# %% [markdown]
# ## De `requests` library
#
# Op het internet zijn heel veel databronnen te vinden. Vaak is het mogelijk om deze databronnen te benaderen via een **Application Programming Interface** ofwel **API**. APIs zijn over het algemeen te benaderen via het `HTTP(s)` protocol. Om vanuit je python code met een externe API te praten, kun je gebruik maken van de `requests` library. De documentatie vind je [hier](https://requests.readthedocs.io/en/latest/).
#
# De `requests` library ondersteunt alle belangrijke [HTTP request methods](https://developer.mozilla.org/en-US/docs/Web/HTTP/Methods). Hieronder staan de meest gebruikte methoden weergegeven
# - `GET` voor het ophalen van een web resource
# - `POST` voor het submitten van data naar een web resource
# - `PUT` voor het submitten van data naar een web resource (idempotent)
# - `PATCH` voor het gedeeltelijk aanpassen van een web resource
# - `DELETE` voor het verwijderen van een web resource
#
# Zoals al eerder gezegd is `json` een dataformat die door veel APIs wordt gebruikt om data heen en weer te sturen tussen een script en het API endpoint. Hier zullen jullie in de opgaven mee gaan oefenen.
#
# ### Een eenvoudig voorbeeld
#
# Hieronder gebruiken we `requests` om een "normale" webpagina op te halen (dit is dus geen API). We printen daarna de headers en de status code van de response

# %%
import requests
response = requests.get("https://www.nos.nl")
print(response.status_code)
print(response.headers)
# Out:
# 200
# {'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'nginx', 'Date': 'Fri, 10 Jan 2025 11:28:48 GMT', 'x-powered-by': 'Next.js', 'ETag': '"cn2fj9zqeuemw9"', 'Content-Encoding': 'gzip', 'strict-transport-security': 'max-age=31536000', 'x-content-type-options': 'nosniff', 'referrer-policy': 'same-origin', 'content-security-policy': "frame-ancestors 'self'", 'x-proxy-cache': 'HIT', 'x-proxy-http-date': 'Fri, 10 Jan 2025 11:28:39 GMT', 'Cache-Control': 'public, s-maxage=1, stale-while-revalidate=600, stale-if-error=86400', 'Vary': 'Accept-Encoding', 'X-Cache': 'RefreshHit from cloudfront', 'Via': '1.1 f58eea4785e4dd62930ab32de2a40d48.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'AMS58-P3', 'X-Amz-Cf-Id': '4UMb4d_Rbi6w7h3oc5bc_A-vEBcP4tQgGOHk_Ds5HTNP4m_OyCiHhQ==', 'Age': '1'}
# <!DOCTYPE html><html lang="nl"><head><meta charSet="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><style>
#     #nprogress {
#       pointer-events: none;
#     }
#     #nprogress .bar {
#       background: #e61e14;
#       position: fixed;
#       z-index: 9999;
#       top: 0;
#       left: 0;
#       width: 100%;
#       height: 3px;
#     }
#     #nprogress .peg {
#       display: block;
#       position: absolute;
#       right: 0px;
#       width: 100px;
#       height: 100%;
#       box-shadow: 0 0 10px #e61e14, 0 0 5px #e61e14;
#       opacity: 1;
#       -webkit-transform: rotate(3deg) translate(0px, -4px);
#       -ms-transform: rotate(3deg) translate(0px, -4px);
#       transform: rotate(3deg) translate(0px, -4px);
#     }
#     #nprogress .spinner {
#       display: block;
#       position: fixed;
#       z-index: 1031;
#       top: 15px;
#       right: 15px;
#     }
#     #nprogress .spinner-icon {
#       width: 18px;
#       height: 18px;
#       box-sizing: border-box;
#       border: solid 2px transparent;
#       border-top-color: #e61e14;
#       border-left-color: #e61e14;
#       border-radius: 50%;
#       -webkit-animation: nprogresss-spinner 400ms linear infinite;
#       animation: nprogress-spinner 400ms linear infinite;
#     }
#     .nprogress-custom-parent {
#       overflow: hidden;
#       position: relative;
#     }
#     .nprogress-custom-parent #nprogress .spinner,
#     .nprogress-custom-parent #nprogress .bar {
#       position: absolute;
#     }
#     @-webkit-keyframes nprogress-spinner {
#       0% {
#         -webkit-transform: rotate(0deg);
#       }
#       100% {
#         -webkit-transform: rotate(360deg);
#       }
#     }
#     @keyframes nprogress-spinner {
#       0% {
#         transform: rotate(0deg);
#       }
#       100% {
#         transform: rotate(360deg);
#       }
#     }
#   </style><title>NOS.nl - Nieuws, Sport en Evenementen | Nederlandse Omroep Stichting</title><link href="https://nos.nl/" rel="canonical"/><meta content="NOS.nl - Nieuws, Sport en Evenementen op Radio, TV en Internet" name="description"/><meta content="Nederlandse Omroep Stichting" name="title"/><meta content="website" property="og:type"/><meta content="https://nos.nl/" property="og:url"/><meta content="Nederlandse Omroep Stichting" property="og:title"/><meta content="NOS.nl - Nieuws, Sport en Evenementen op Radio, TV en Internet" property="og:description"/><meta content="https://static.nos.nl/img/nos/nos-social.jpg" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="630" property="og:image:height"/><meta content="app" property="twitter:card"/><meta content="@NOS" property="twitter:site"/><meta content="https://static.nos.nl/img/nos/nos-social.jpg" name="thumbnail"/><meta content="id516491461" property="twitter:app:id:iphone"/><meta content="nl.nos.app://open" property="twitter:app:url:iphone"/><meta content="id516491461" property="twitter:app:id:ipad"/><meta content="nl" property="twitter:app:country"/><meta content="nl.nos.app://open" property="twitter:app:url:ipad"/><meta content="nl.nos.app" property="twitter:app:id:googleplay"/><link href="https://static.nos.nl/img/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://static.nos.nl/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://static.nos.nl/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link color="#e61e14" href="https://static.nos.nl/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/><link href="https://static.nos.nl/img/favicon/favicon.ico" rel="shortcut icon"/><meta content="NOS.nl" name="apple-mobile-web-app-title"/><meta content="NOS.nl" name="application-name"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="#ffffff" name="theme-color"/><link href="/static/site.webmanifest.light" rel="manifest"/><meta content="/static/browserconfig.xml" name="msapplication-config"/><meta name="next-head-count" content="34"/><meta content="PFlpDv56X7yQ8CtMDAxvMIyOWtfO8puTcDbndM0veTY" name="google-site-verification"/><meta content="NOS" name="app-name"/><meta content="app-id=516491461" name="apple-itunes-app"/><meta content="app-id=nl.nos.app" name="google-play-app"/><script>var hasWindowAndDocument = !!(typeof window !== 'undefined' && document);
#             if (hasWindowAndDocument && !!window.MSInputMethodContext && !!document.documentMode) {
#               if (window.location.pathname !== '/geen-ondersteuning') {
#                 window.location.replace(window.location.origin + '/geen-ondersteuning');
#               }
#             }</script><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/chunks/polyfills-42372ed130431b0a.js"></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/webpack.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/framework.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/main.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/pages/_app.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/d6e1aeb5.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/4967.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/9532.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/7829.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/7693.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/6212.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/1514.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/2181.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/8764.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/7915.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/5840.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/5935.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/9398.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/9952.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/1295.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/5273.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/1162.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/9606.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/8566.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/2158.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/5120.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/5690.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/986.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/pages/index.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_next/static/1551713ed4a8f4e07f42e67de4468173fbb1acdd/_buildManifest.js" defer=""></script><script src="https://cdn.nos.nl/assets/nosnl/15 ...
#           @font-face {
#             font-family: 'Effra';
#             font-style: normal;
#             font-display: block;
#             font-weight: 400;
#             src: local('EffraRegular'), local('EffraRegular'),
#               url('https://static.nos.nl/fonts/effra/EffraRegular.woff?v=prod-app') format('woff'),
#               url('https://static.nos.nl/fonts/effra/EffraRegular.woff2?v=prod-app') format('woff2');
#           }
#
#           @font-face {
#             font-family: 'Effra-Bold';
#             font-style: normal;
#             font-display: block;
#             font-weight: 700;
#             src: local('EffraBold'), local('EffraBold'),
#               url('https://static.nos.nl/fonts/effra/EffraBold.woff?v=prod-app') format('woff'),
#               url('https://static.nos.nl/fonts/effra/EffraBold.woff2?v=prod-app') format('woff2');
#           }
#
#           @font-face {
#             font-family: 'Karla';
#             font-style: normal;
#             font-display: block;
#             font-weight: 400;
#             src: local('Karla'), local('Karla'),
#               url('https://static.nos.nl/fonts/karla/Karla-Regular.ttf?v=prod-app') format('truetype');
#           }
#
#           @font-face {
#             font-family: 'Karla';
#             font-style: italic;
#             font-display: block;
#             font-weight: 400;
#             src: local('Karla'), local('Karla'),
#               url('https://static.nos.nl/fonts/karla/Karla-Italic.ttf?v=prod-app') format('truetype');
#           }
#
#           @font-face {
#             font-family: 'Karla';
#             font-style: normal;
#             font-display: block;
#             font-weight: 700;
#             src: local('Karla'), local('Karla'),
#               url('https://static.nos.nl/fonts/karla/Karla-Bold.ttf?v=prod-app') format('truetype');
#           }
#
#           @font-face {
#             font-family: 'Merriweather';
#             font-style: normal;
#             font-display: block;
#             font-weight: 700;
#             src: local('Merriweather'), local('Merriweather'),
#               url('https://static.nos.nl/fonts/merriweather/Merriweather-Bold.ttf?v=prod-app') format('truetype');
#           }
#         </style><style data-styled="" data-styled-version="5.3.11">html{line-height:1.15;-webkit-text-size-adjust:100%;}/*!sc*/
# body{margin:0;}/*!sc*/
# main{display:block;}/*!sc*/
# h1{font-size:2em;margin:0.67em 0;}/*!sc*/
# hr{box-sizing:content-box;height:0;overflow:visible;}/*!sc*/
# pre{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# a{background-color:transparent;}/*!sc*/
# abbr[title]{border-bottom:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted;}/*!sc*/
# b,strong{font-weight:bolder;}/*!sc*/
# code,kbd,samp{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# small{font-size:80%;}/*!sc*/
# sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}/*!sc*/
# sub{bottom:-0.25em;}/*!sc*/
# sup{top:-0.5em;}/*!sc*/
# img{border-style:none;}/*!sc*/
# button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0;}/*!sc*/
# button,input{overflow:visible;}/*!sc*/
# button,select{text-transform:none;}/*!sc*/
# button,[type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button;}/*!sc*/
# button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0;}/*!sc*/
# button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText;}/*!sc*/
# fieldset{padding:0.35em 0.75em 0.625em;}/*!sc*/
# legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal;}/*!sc*/
# progress{vertical-align:baseline;}/*!sc*/
# textarea{overflow:auto;}/*!sc*/
# [type="checkbox"],[type="radio"]{box-sizing:border-box;padding:0;}/*!sc*/
# [type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto;}/*!sc*/
# [type="search"]{-webkit-appearance:textfield;outline-offset:-2px;}/*!sc*/
# [type="search"]::-webkit-search-decoration{-webkit-appearance:none;}/*!sc*/
# ::-webkit-file-upload-button{-webkit-appearance:button;font:inherit;}/*!sc*/
# details{display:block;}/*!sc*/
# summary{display:list-item;}/*!sc*/
# template{display:none;}/*!sc*/
# [hidden]{display:none;}/*!sc*/
# data-styled.g1[id="sc-global-ecVvVt1"]{content:"sc-global-ecVvVt1,"}/*!sc*/
# *,*:before,*:after{box-sizing:border-box;margin:0;padding:0;}/*!sc*/
# html,body{height:100%;-webkit-text-size-adjust:100%;-webkit-tap-highlight-color:transparent;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-rendering:optimizeLegibility;font-feature-settings:"liga","kern";font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font-size:1rem;background-color:#ffffff;}/*!sc*/
# body{-webkit-scroll-behavior:smooth;-moz-scroll-behavior:smooth;-ms-scroll-behavior:smooth;scroll-behavior:smooth;}/*!sc*/
# .usabilla_live_button_container{display:none;}/*!sc*/
# fieldset{border:none;padding:0;}/*!sc*/
# #content:focus{outline:unset;}/*!sc*/
# svg{overflow-clip-margin:1px;}/*!sc*/
# data-styled.g2[id="sc-global-kWfyGg1"]{content:"sc-global-kWfyGg1,"}/*!sc*/
# .kXgLFt{position:absolute;overflow:hidden;-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);width:1px;height:1px;white-space:nowrap;font-size:0;}/*!sc*/
# data-styled.g3[id="sc-589e9f18-0"]{content:"kXgLFt,"}/*!sc*/
# .cbOXNi{overflow-wrap:anywhere;margin:0;padding:0;font-weight:700;font-size:2.125rem;line-height:1.2;}/*!sc*/
# data-styled.g10[id="sc-773b561e-0"]{content:"cbOXNi,"}/*!sc*/
# .eiGbry{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row nowrap;-ms-flex-flow:row nowrap;flex-flow:row nowrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:1rem 1rem 1rem 0;}/*!sc*/
# .eiGbry > svg:first-child{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;width:3rem;}/*!sc*/
# data-styled.g25[id="sc-1ca8b3a3-0"]{content:"eiGbry,"}/*!sc*/
# .hmkFoj{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;margin-left:1rem;}/*!sc*/
# data-styled.g26[id="sc-1ca8b3a3-1"]{content:"hmkFoj,"}/*!sc*/
# .lmmcyI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 0 3rem;-ms-flex:0 0 3rem;flex:0 0 3rem;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:3rem;height:3rem;border-radius:50%;background-color:#ffffff;}/*!sc*/
# .lmmcyI svg{color:#e61e14;}/*!sc*/
# data-styled.g27[id="sc-1ca8b3a3-2"]{content:"lmmcyI,"}/*!sc*/
# .iSXGiG{display:block;margin-bottom:0.25rem;color:#202020;font-weight:500;font-size:1rem;line-height:1;-webkit-transition:all 150ms ease-in-out;transition:all 150ms ease-in-out;}/*!sc*/
# data-styled.g28[id="sc-1ca8b3a3-3"]{content:"iSXGiG,"}/*!sc*/
# .dtQKJA{display:block;color:#666666;font-size:0.875rem;}/*!sc*/
# data-styled.g29[id="sc-1ca8b3a3-4"]{content:"dtQKJA,"}/*!sc*/
# .gPtzXr{overflow-wrap:anywhere;display:block;color:#202020;-webkit-text-decoration:none;text-decoration:none;font-weight:500;line-height:1.14;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# @media (hover:hover) and (pointer:fine),only screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.gPtzXr:hover{color:#e61e14;}.gPtzXr:hover .sc-1ca8b3a3-3{-webkit-text-decoration:underline;text-decoration:underline;color:#e61e14;}.gPtzXr:hover .sc-1ca8b3a3-5{-webkit-transform:translate(0.1em,-0.1em);-ms-transform:translate(0.1em,-0.1em);transform:translate(0.1em,-0.1em);}}/*!sc*/
# .gPtzXr:focus-visible{outline:0.125rem solid #e61e14;outline-offset:0.125rem;border-radius:0.125rem;}/*!sc*/
# .gPtzXr:active{color:#e61e14;-webkit-transition:none;transition:none;}/*!sc*/
# .gPtzXr:active .sc-1ca8b3a3-3{color:inherit;}/*!sc*/
# data-styled.g31[id="sc-de96cd8-0"]{content:"gPtzXr,"}/*!sc*/
# .kjXHcW{margin-top:2.5rem;border-top:1px solid #eeeeee;border-bottom:1px solid #eeeeee;background-color:#ffffff;color:#666666;}/*!sc*/
# @media print{.kjXHcW{display:none;}}/*!sc*/
# data-styled.g32[id="sc-7dd6bf2c-0"]{content:"kjXHcW,"}/*!sc*/
# .eanIBM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media (min-width:760px){.eanIBM{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;max-width:75rem;margin:0 auto;padding:2rem 1rem 0;}}/*!sc*/
# data-styled.g33[id="sc-7dd6bf2c-1"]{content:"eanIBM,"}/*!sc*/
# .cURnmi{overflow-wrap:anywhere;margin:1rem 0;color:#e61e14;font-weight:500;font-size:1.125rem;font-family:'Effra-Bold',Helvetica,Arial,sans-serif;}/*!sc*/
# data-styled.g34[id="sc-7dd6bf2c-2"]{content:"cURnmi,"}/*!sc*/
# .jhSSat{margin:1rem 0 0;padding:0;list-style:none;}/*!sc*/
# data-styled.g35[id="sc-7dd6bf2c-3"]{content:"jhSSat,"}/*!sc*/
# .fmOQEr{display:inline-block;margin-bottom:1rem;color:#666666;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0.01875rem;-moz-letter-spacing:0.01875rem;-ms-letter-spacing:0.01875rem;letter-spacing:0.01875rem;font-weight:500;line-height:1.13;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# @media (hover:hover) and (pointer:fine),only screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.fmOQEr:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#e61e14;}}/*!sc*/
# .fmOQEr:focus-visible{outline:2px solid #e61e14;outline-offset:0.25rem;border-radius:0.0625rem;}/*!sc*/
# .fmOQEr:active{color:#e61e14;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g36[id="sc-7dd6bf2c-4"]{content:"fmOQEr,"}/*!sc*/
# .bCEzFR{-webkit-flex-shrink:2;-ms-flex-negative:2;flex-shrink:2;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media (min-width:760px){.bCEzFR{padding-top:2rem;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:18.75rem;-ms-flex-preferred-size:18.75rem;flex-basis:18.75rem;display:none;}}/*!sc*/
# .kaztbd{-webkit-flex-shrink:2;-ms-flex-negative:2;flex-shrink:2;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;display:none;}/*!sc*/
# @media (min-width:760px){.kaztbd{padding-top:2rem;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:18.75rem;-ms-flex-preferred-size:18.75rem;flex-basis:18.75rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# data-styled.g37[id="sc-7dd6bf2c-5"]{content:"bCEzFR,kaztbd,"}/*!sc*/
# .jgAuah{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0 1rem 2rem;border-top:1px solid #eeeeee;}/*!sc*/
# @media (min-width:760px){.jgAuah{width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:2rem 1rem 2rem 0;border-top:0;}}/*!sc*/
# @media (min-width:900px){.jgAuah{padding:2rem 5rem 2rem 0;}}/*!sc*/
# data-styled.g38[id="sc-7dd6bf2c-6"]{content:"jgAuah,"}/*!sc*/
# .kgqVnY{display:none;margin-right:2.5rem;}/*!sc*/
# .kgqVnY:first-child{display:block;}/*!sc*/
# @media (min-width:760px){.kgqVnY{display:block;}}/*!sc*/
# data-styled.g39[id="sc-7dd6bf2c-7"]{content:"kgqVnY,"}/*!sc*/
# .fePlRH{border-top:1px solid #eeeeee;}/*!sc*/
# data-styled.g40[id="sc-7dd6bf2c-8"]{content:"fePlRH,"}/*!sc*/
# .btqrAa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-top:2rem;}/*!sc*/
# @media (min-width:760px){.btqrAa{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;max-width:75rem;margin:0 auto;padding:0 1rem;}}/*!sc*/
# data-styled.g41[id="sc-7dd6bf2c-9"]{content:"btqrAa,"}/*!sc*/
# .zsppb{padding:1rem 1rem;border-bottom:1px solid #eeeeee;-webkit-transition:none;transition:none;}/*!sc*/
# @media (min-width:760px){.zsppb{padding:1rem 1rem 1rem 0;}}/*!sc*/
# .zsppb:last-child{border-bottom:0;}/*!sc*/
# .zsppb .sc-1ca8b3a3-2{background-color:#f3f3f0;}/*!sc*/
# .zsppb .sc-1ca8b3a3-0{padding:0;}/*!sc*/
# .zsppb:hover .sc-1ca8b3a3-3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .zsppb:focus-visible{outline:2px solid #e61e14;outline-offset:-0.125rem;border-radius:0.25rem;}/*!sc*/
# data-styled.g42[id="sc-7dd6bf2c-10"]{content:"zsppb,"}/*!sc*/
# .hUmQHW{padding:1rem;border:none;border-bottom:1px solid #eeeeee;background:none;text-align:left;font-weight:500;cursor:pointer;}/*!sc*/
# @media (min-width:760px){.hUmQHW{padding-left:0;}}/*!sc*/
# .hUmQHW .sc-1ca8b3a3-2{background-color:#f3f3f0;}/*!sc*/
# .hUmQHW .sc-1ca8b3a3-0{padding:0;}/*!sc*/
# .hUmQHW:hover .sc-1ca8b3a3-3{color:#e61e14;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hUmQHW:focus-visible{outline:2px solid #e61e14;outline-offset:-0.125rem;border-radius:0.25rem;}/*!sc*/
# data-styled.g43[id="sc-7dd6bf2c-11"]{content:"hUmQHW,"}/*!sc*/
# .bcwjoD{-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# .bcwjoD svg{height:1.75rem;color:#949494;}/*!sc*/
# .bcwjoD:hover{-webkit-transform:scale(1.025);-ms-transform:scale(1.025);transform:scale(1.025);}/*!sc*/
# .bcwjoD:focus-visible{outline:2px solid #e61e14;outline-offset:0.25rem;border-radius:0.0625rem;}/*!sc*/
# data-styled.g44[id="sc-7dd6bf2c-12"]{content:"bcwjoD,"}/*!sc*/
# .jBKERJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:1rem;padding:1.5rem 1rem 2.5rem;width:100%;border-top:1px solid #eeeeee;}/*!sc*/
# @media (min-width:760px){.jBKERJ{-webkit-order:1;-ms-flex-order:1;order:1;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin-left:3.125rem;margin-top:0;border-top:0;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:2rem 0;}}/*!sc*/
# data-styled.g45[id="sc-7dd6bf2c-13"]{content:"jBKERJ,"}/*!sc*/
# .bVjlHE{font:500 0.875rem/1.29 'Helvetica Neue',Helvetica,Arial,sans-serif;margin-right:0.75rem;}/*!sc*/
# @media (min-width:760px){.bVjlHE{margin-right:2rem;font:500 1rem/1.375 'Helvetica Neue',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g46[id="sc-7dd6bf2c-14"]{content:"bVjlHE,"}/*!sc*/
# .hwSzOw{margin-right:0.75rem;color:#666666;font:500 0.875rem/1.29 'Helvetica Neue',Helvetica,Arial,sans-serif;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# .hwSzOw:last-child{margin:0%;}/*!sc*/
# .hwSzOw:hover{color:#e61e14;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hwSzOw:focus-visible{outline:2px solid #e61e14;outline-offset:0.25rem;border-radius:0.0625rem;}/*!sc*/
# @media (min-width:760px){.hwSzOw{margin-right:2rem;font:500 1rem/1.375 'Helvetica Neue',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g47[id="sc-7dd6bf2c-15"]{content:"hwSzOw,"}/*!sc*/
# .gHEInl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:2rem;height:2rem;border-radius:50%;background-color:#e61e14;color:#ffffff;opacity:1;-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# .gHEInl svg{-webkit-transform:scale(0.8);-ms-transform:scale(0.8);transform:scale(0.8);}/*!sc*/
# .gHEInl:hover{-webkit-transform:scale(1.0625);-ms-transform:scale(1.0625);transform:scale(1.0625);background-color:#ca1a12;}/*!sc*/
# .gHEInl:focus-visible{outline:2px solid #e61e14;outline-offset:0.125rem;}/*!sc*/
# data-styled.g48[id="sc-9610c20e-0"]{content:"gHEInl,"}/*!sc*/
# .htNsAP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:0.6875rem;}/*!sc*/
# @media (min-width:760px){.htNsAP{-webkit-order:3;-ms-flex-order:3;order:3;margin-top:0;}}/*!sc*/
# data-styled.g49[id="sc-8404c505-0"]{content:"htNsAP,"}/*!sc*/
# .hEvqka{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;margin:0.625rem;background-color:#e61e14;color:distinct:#ffffff;}/*!sc*/
# @media (min-width:760px){.hEvqka{margin-right:0;margin-left:1.25rem;}}/*!sc*/
# data-styled.g50[id="sc-8404c505-1"]{content:"hEvqka,"}/*!sc*/
# .dTHQDl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:2.5rem;height:2.5rem;outline:0.125rem solid rgba(230,30,20,0);outline-offset:0.125rem;border:none;border-radius:50%;background-color:#ffffff;box-shadow:0 0.125rem 0.625rem 0 rgba(0,0,0,0.2);color:#e61e14;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;-webkit-transition:box-shadow 300ms ease-in-out,outline 150ms ease-in-out;transition:box-shadow 300ms ease-in-out,outline 150ms ease-in-out;}/*!sc*/
# .dTHQDl svg{-webkit-flex:0 0 1.25rem;-ms-flex:0 0 1.25rem;flex:0 0 1.25rem;}/*!sc*/
# .dTHQDl:hover{box-shadow:0 0.125rem 0.625rem 0 rgba(0,0,0,0.4);}/*!sc*/
# .dTHQDl:focus-visible{outline:0.125rem solid rgba(230,30,20,1);}/*!sc*/
# data-styled.g52[id="sc-55ae61eb-0"]{content:"dTHQDl,"}/*!sc*/
# .coISAx{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;color:#666666;}/*!sc*/
# data-styled.g53[id="sc-79374b6d-0"]{content:"coISAx,"}/*!sc*/
# .vHpsu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 0.375rem;height:100%;border:none;background-color:#ffffff;color:#e61e14;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0.0167rem;-moz-letter-spacing:0.0167rem;-ms-letter-spacing:0.0167rem;letter-spacing:0.0167rem;font-weight:500;font-size:1rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;font:500 0.875rem/1.29 'Helvetica Neue',Helvetica,Arial,sans-serif;}/*!sc*/
# .vHpsu:hover{color:#e61e14;}/*!sc*/
# .vHpsu:focus-visible{outline:2px solid #e61e14;outline-offset:-2px;border-radius:0.25rem;}/*!sc*/
# @media (min-width:375px){.vHpsu{font:500 1rem/1.375 'Helvetica Neue',Helvetica,Arial,sans-serif;}}/*!sc*/
# @media (min-width:600px){.vHpsu{padding:0 0.75rem;}}/*!sc*/
# @media (min-width:760px){.vHpsu{padding:0 1rem;}}/*!sc*/
# @media (min-width:1100px){.vHpsu{font:500 1.125rem/1.33 'Helvetica Neue',Helvetica,Arial,sans-serif;padding:0 1.25rem;}}/*!sc*/
# .gUOeao{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 0.375rem;height:100%;border:none;background-color:#ffffff;color:#666666;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0.0167rem;-moz-letter-spacing:0.0167rem;-ms-letter-spacing:0.0167rem;letter-spacing:0.0167rem;font-weight:500;font-size:1rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;font:500 0.875rem/1.29 'Helvetica Neue',Helvetica,Arial,sans-serif;}/*!sc*/
# .gUOeao:hover{color:#e61e14;}/*!sc*/
# .gUOeao:focus-visible{outline:2px solid #e61e14;outline-offset:-2px;border-radius:0.25rem;}/*!sc*/
# @media (min-width:375px){.gUOeao{font:500 1rem/1.375 'Helvetica Neue',Helvetica,Arial,sans-serif;}}/*!sc*/
# @media (min-width:600px){.gUOeao{padding:0 0.75rem;}}/*!sc*/
# @media (min-width:760px){.gUOeao{padding:0 1rem;}}/*!sc*/
# @media (min-width:1100px){.gUOeao{font:500 1.125rem/1.33 'Helvetica Neue',Helvetica,Arial,sans-serif;padding:0 1.25rem;}}/*!sc*/
# data-styled.g54[id="sc-79374b6d-1"]{content:"vHpsu,gUOeao,"}/*!sc*/
# .EwlHo{width:1.25rem;height:1.25rem;}/*!sc*/
# @media (min-width:375px){.EwlHo{width:1.5rem;height:1.5rem;}}/*!sc*/
# data-styled.g55[id="sc-ea33ef4c-0"]{content:"EwlHo,"}/*!sc*/
# .gsksoL{height:100%;}/*!sc*/
# data-styled.g59[id="sc-ea33ef4c-4"]{content:"gsksoL,"}/*!sc*/
# .hRdMlk{position:relative;height:100%;color:#202020;}/*!sc*/
# data-styled.g60[id="sc-ea33ef4c-5"]{content:"hRdMlk,"}/*!sc*/
# .gXilRh{padding:0 0.5625rem;cursor:pointer;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# @media (min-width:375px){.gXilRh{padding:0.625rem;}}/*!sc*/
# @media (min-width:760px){.gXilRh{margin-right:0.5rem;}}/*!sc*/
# .gXilRh.gXilRh:focus-visible{outline:0.125rem solid #e61e14;outline-offset:-0.125rem;border-radius:0.25rem;}/*!sc*/
# .gXilRh[aria-expanded='true'] + .sc-ea33ef4c-6{display:block;}/*!sc*/
# data-styled.g62[id="sc-ea33ef4c-7"]{content:"gXilRh,"}/*!sc*/
# .hwFyRg{position:relative;}/*!sc*/
# data-styled.g85[id="sc-1efe975a-0"]{content:"hwFyRg,"}/*!sc*/
# .iQWMwu{gap:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;margin:0;padding:0;height:100%;list-style:none;}/*!sc*/
# @media (min-width:375px){.iQWMwu{gap:0.125rem;}}/*!sc*/
# @media (min-width:600px){.iQWMwu{gap:0.25rem;}}/*!sc*/
# data-styled.g86[id="sc-1efe975a-1"]{content:"iQWMwu,"}/*!sc*/
# .hBAgok{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;}/*!sc*/
# @media (min-width:760px){.hBAgok{padding:0 0.75rem;}}/*!sc*/
# @media (min-width:900px){.hBAgok{display:none;}}/*!sc*/
# data-styled.g87[id="sc-1efe975a-2"]{content:"hBAgok,"}/*!sc*/
# .feEcab{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 0.5rem;height:100%;color:#949494;-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# .feEcab svg{display:block;width:65px;}/*!sc*/
# @media (max-width:450px){.feEcab svg{width:auto;height:0.875rem;}}/*!sc*/
# @media (min-width:calc(450px + 1px)) and (max-width:760px){.feEcab svg{width:auto;height:1rem;}}/*!sc*/
# .feEcab:hover{-webkit-transform:scale(1.025);-ms-transform:scale(1.025);transform:scale(1.025);}/*!sc*/
# .feEcab:focus-visible{outline:2px solid #e61e14;outline-offset:-2px;border-radius:0.25rem;}/*!sc*/
# data-styled.g88[id="sc-1efe975a-3"]{content:"feEcab,"}/*!sc*/
# .iaoBlq{margin:0.1875rem;width:1.25rem;height:1.25rem;}/*!sc*/
# @media (min-width:375px){.iaoBlq{margin:0.25rem;width:1.5rem;height:1.5rem;}}/*!sc*/
# data-styled.g89[id="sc-1efe975a-4"]{content:"iaoBlq,"}/*!sc*/
# .bbkuON{margin:0.1875rem;width:1.25rem;height:1.25rem;-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# @media (min-width:375px){.bbkuON{margin:0.25rem;width:1.5rem;height:1.5rem;}}/*!sc*/
# data-styled.g90[id="sc-1efe975a-5"]{content:"bbkuON,"}/*!sc*/
# .fwLghv{width:0.5rem;margin:0.25rem 0 0 0.25rem;}/*!sc*/
# data-styled.g91[id="sc-1efe975a-6"]{content:"fwLghv,"}/*!sc*/
# .fwkWTc{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g93[id="sc-c0b56039-1"]{content:"fwkWTc,"}/*!sc*/
# .bWyhkx{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;}/*!sc*/
# @media (max-width:calc(900px - 1px)){.bWyhkx{display:none;}}/*!sc*/
# @media (min-width:900px){.bWyhkx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# data-styled.g94[id="sc-c0b56039-2"]{content:"bWyhkx,"}/*!sc*/
# .iCQJou:not(:last-child) .sc-79374b6d-1{padding-right:0.5rem;}/*!sc*/
# .iCQJou:before{width:1px;height:1.5rem;border-left:1px solid #dddddd;content:'';}/*!sc*/
# data-styled.g95[id="sc-c0b56039-3"]{content:"iCQJou,"}/*!sc*/
# .enQSCv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0 1rem;height:100%;color:#949494;-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# .enQSCv svg{display:block;}/*!sc*/
# .enQSCv:hover{-webkit-transform:scale(1.025);-ms-transform:scale(1.025);transform:scale(1.025);}/*!sc*/
# .enQSCv:focus-visible{outline:2px solid #e61e14;outline-offset:-2px;border-radius:4px;}/*!sc*/
# data-styled.g96[id="sc-c0b56039-4"]{content:"enQSCv,"}/*!sc*/
# .mTGxJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 1rem;height:100%;color:#666666;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0.0167rem;-moz-letter-spacing:0.0167rem;-ms-letter-spacing:0.0167rem;letter-spacing:0.0167rem;font-weight:500;font-size:1rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# .mTGxJ:hover{color:#e61e14;}/*!sc*/
# .mTGxJ:focus-visible{outline:2px solid #e61e14;outline-offset:-2px;border-radius:4px;}/*!sc*/
# @media (min-width:1100px){.mTGxJ{font-size:1.125rem;}}/*!sc*/
# data-styled.g97[id="sc-c0b56039-5"]{content:"mTGxJ,"}/*!sc*/
# .csGGQC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;margin:0;padding:0;height:100%;list-style:none;}/*!sc*/
# data-styled.g98[id="sc-c0b56039-6"]{content:"csGGQC,"}/*!sc*/
# .kNjOhz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;margin:0;padding:0;height:100%;list-style:none;}/*!sc*/
# data-styled.g99[id="sc-c0b56039-7"]{content:"kNjOhz,"}/*!sc*/
# .jDrBGf{width:1.875rem;height:auto;}/*!sc*/
# @media (min-width:1100px){.jDrBGf{width:2rem;}}/*!sc*/
# data-styled.g100[id="sc-c0b56039-8"]{content:"jDrBGf,"}/*!sc*/
# .epbWcF{width:1.375rem;height:auto;}/*!sc*/
# @media (min-width:1100px){.epbWcF{width:1.5rem;}}/*!sc*/
# data-styled.g101[id="sc-c0b56039-9"]{content:"epbWcF,"}/*!sc*/
# .lcaEmn{width:2.0625rem;height:auto;}/*!sc*/
# @media (min-width:1100px){.lcaEmn{width:2.25rem;}}/*!sc*/
# data-styled.g102[id="sc-c0b56039-10"]{content:"lcaEmn,"}/*!sc*/
# .jXoiUS{width:1.375rem;height:auto;-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# @media (min-width:1100px){.jXoiUS{width:1.5rem;}}/*!sc*/
# data-styled.g103[id="sc-c0b56039-11"]{content:"jXoiUS,"}/*!sc*/
# .bezXoB{width:0.5em;margin:0.25em 0 0 0.25em;}/*!sc*/
# data-styled.g104[id="sc-c0b56039-12"]{content:"bezXoB,"}/*!sc*/
# .leeTmg{width:70px;color:#949494;}/*!sc*/
# data-styled.g105[id="sc-c0b56039-13"]{content:"leeTmg,"}/*!sc*/
# .eoiamV .sc-481b4db4-1{position:absolute;top:-1rem;right:-0.875rem;}/*!sc*/
# data-styled.g106[id="sc-c0b56039-14"]{content:"eoiamV,"}/*!sc*/
# .dXvoqD{z-index:999;padding:0 0.5rem;height:4.375rem;border-bottom:1px solid #dddddd;background-color:#ffffff;box-shadow:0 0.125rem 0.25rem 0 rgba(0,0,0,0.12);position:-webkit-sticky;position:sticky;top:0;}/*!sc*/
# @media (min-width:760px){.dXvoqD{position:-webkit-sticky;position:sticky;top:0;padding:0;}@media (min-width:760px){.dXvoqD{margin-bottom:2rem;}}}/*!sc*/
# @media (min-width:900px){.dXvoqD{margin-bottom:2.5rem;}}/*!sc*/
# @media print{.dXvoqD{display:none;}}/*!sc*/
# data-styled.g107[id="sc-70b3272e-0"]{content:"dXvoqD,"}/*!sc*/
# .jlLrrj{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;margin:0 auto;max-width:75rem;width:100%;height:100%;}/*!sc*/
# data-styled.g108[id="sc-70b3272e-1"]{content:"jlLrrj,"}/*!sc*/
# .gOWfGa{position:absolute;top:4rem;left:0;z-index:2;margin:0;padding:0;list-style:none;}/*!sc*/
# data-styled.g109[id="sc-97bf28f2-0"]{content:"gOWfGa,"}/*!sc*/
# .iKAwXw{display:block;padding:1rem;background-color:#ffffff;color:#e61e14;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .iKAwXw:not(:focus):not(:active){position:absolute;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);width:0.0625rem;height:0.0625rem;white-space:nowrap;}/*!sc*/
# .iKAwXw:focus-visible{outline:0.125rem solid #e61e14;outline-offset:0.125rem;border-radius:0.125rem;}/*!sc*/
# data-styled.g110[id="sc-97bf28f2-1"]{content:"iKAwXw,"}/*!sc*/
# .JQmZY{top:1.25rem;left:2.25rem;}/*!sc*/
# @media (min-width:900px){.JQmZY{top:1.25rem;left:7.5rem;}}/*!sc*/
# .JQmZY .sc-97bf28f2-1{border-radius:0.375rem;box-shadow:0 0.9375rem 1.875rem 0 rgba(0,0,0,0.15);color:#e61e14;font-weight:700;}/*!sc*/
# .JQmZY .sc-97bf28f2-1:focus-visible{outline:0.125rem solid #e61e14;outline-offset:0.125rem;border-radius:0.125rem;}/*!sc*/
# data-styled.g111[id="sc-231324e8-0"]{content:"JQmZY,"}/*!sc*/
# .eYVouA{position:absolute;top:4rem;right:0;left:0;z-index:3;margin:0;padding:0;list-style:none;}/*!sc*/
# data-styled.g112[id="sc-5756b926-0"]{content:"eYVouA,"}/*!sc*/
# .caYZvr{width:100%;height:100%;}/*!sc*/
# data-styled.g113[id="sc-5756b926-1"]{content:"caYZvr,"}/*!sc*/
# .ekOwtd{top:0;left:0.375rem;}/*!sc*/
# data-styled.g114[id="sc-5756b926-2"]{content:"ekOwtd,"}/*!sc*/
# .dVctfw{position:absolute;top:0;right:0;bottom:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g115[id="sc-67cf2978-0"]{content:"dVctfw,"}/*!sc*/
# .dajunI{object-fit:cover;position:absolute;top:0;right:0;bottom:0;left:0;width:100%;height:100%;background-color:#f3f3f0;}/*!sc*/
# data-styled.g116[id="sc-67cf2978-1"]{content:"dajunI,"}/*!sc*/
# .giwFcp{position:absolute;top:0;right:0;bottom:0;left:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;background-color:#f3f3f0;}/*!sc*/
# data-styled.g117[id="sc-eacf7402-0"]{content:"giwFcp,"}/*!sc*/
# .bHSJue{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;background-color:#ffffff;-webkit-letter-spacing:0.3px;-moz-letter-spacing:0.3px;-ms-letter-spacing:0.3px;letter-spacing:0.3px;}/*!sc*/
# .bHSJue:after{position:absolute;right:0;bottom:0;left:1rem;height:1px;background-color:#eeeeee;content:'';}/*!sc*/
# .bHSJue:last-child:after{content:none;}/*!sc*/
# data-styled.g161[id="sc-dde794d8-0"]{content:"bHSJue,"}/*!sc*/
# .bTYIYA{-webkit-transition:opacity 300ms ease-in-out;transition:opacity 300ms ease-in-out;}/*!sc*/
# data-styled.g365[id="sc-102ec126-0"]{content:"bTYIYA,"}/*!sc*/
# .bHdduI{width:3.75rem;height:3.75rem;-webkit-transition:box-shadow 300ms ease-in-out,opacity 300ms ease-in-out;transition:box-shadow 300ms ease-in-out,opacity 300ms ease-in-out;}/*!sc*/
# .bHdduI[disabled]{opacity:0;pointer-events:none;}/*!sc*/
# data-styled.g366[id="sc-102ec126-1"]{content:"bHdduI,"}/*!sc*/
# .bkeWYe{color:#e61e14;}/*!sc*/
# data-styled.g367[id="sc-102ec126-2"]{content:"bkeWYe,"}/*!sc*/
# .QkFiq{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}/*!sc*/
# data-styled.g368[id="sc-102ec126-3"]{content:"QkFiq,"}/*!sc*/
# .zXysl{position:absolute;top:50%;}/*!sc*/
# .zXysl:hover{background-color:#f3f3f0;color:#666666;}/*!sc*/
# data-styled.g369[id="sc-102ec126-4"]{content:"zXysl,"}/*!sc*/
# .gYFFAU{left:2.5rem;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}/*!sc*/
# data-styled.g370[id="sc-102ec126-5"]{content:"gYFFAU,"}/*!sc*/
# .tLJkT{right:2.5rem;-webkit-transform:translate(50%,-50%);-ms-transform:translate(50%,-50%);transform:translate(50%,-50%);}/*!sc*/
# data-styled.g371[id="sc-102ec126-6"]{content:"tLJkT,"}/*!sc*/
# @media (min-width:760px){.cQaHjk{-webkit-mask-image:linear-gradient( 90deg,black 0%,black 1.5rem,black calc(100% - 1.5rem),black 100% );mask-image:linear-gradient( 90deg,black 0%,black 1.5rem,black calc(100% - 1.5rem),black 100% );}}/*!sc*/
# data-styled.g372[id="sc-673a092e-0"]{content:"cQaHjk,"}/*!sc*/
# .zmjfx{position:relative;}/*!sc*/
# .zmjfx .sc-102ec126-0{opacity:0;pointer-events:none;}/*!sc*/
# @media (min-width:760px){.zmjfx:hover .sc-102ec126-0{opacity:1;pointer-events:initial;}}/*!sc*/
# data-styled.g373[id="sc-673a092e-1"]{content:"zmjfx,"}/*!sc*/
# .ipTbnu{overflow:hidden;width:100%;}/*!sc*/
# data-styled.g374[id="sc-673a092e-2"]{content:"ipTbnu,"}/*!sc*/
# .fpMOrd{gap:1rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;padding:0.375rem 0;list-style-type:'';}/*!sc*/
# data-styled.g375[id="sc-673a092e-3"]{content:"fpMOrd,"}/*!sc*/
# .kKsoIR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g376[id="sc-2e00ab9a-0"]{content:"kKsoIR,"}/*!sc*/
# .jUxBWa{font:bold 1.25rem/1.1 'Effra-Bold',Helvetica,Arial,sans-serif;color:#202020;}/*!sc*/
# @media (min-width:760px){.jUxBWa{font:bold 1.375rem/1.09 'Effra-Bold',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g377[id="sc-2e00ab9a-1"]{content:"jUxBWa,"}/*!sc*/
# .kDhPYE{width:1rem;-webkit-transform:rotate(-90deg);-ms-transform:rotate(-90deg);transform:rotate(-90deg);}/*!sc*/
# data-styled.g378[id="sc-2e00ab9a-2"]{content:"kDhPYE,"}/*!sc*/
# .iNoavZ{font:bold 0.75rem/1.16 'Effra-Bold',Helvetica,Arial,sans-serif;gap:0.25rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;color:#666666;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# .iNoavZ:hover{color:#e61e14;}/*!sc*/
# @media (min-width:760px){.iNoavZ{font:bold 0.875rem/1.14 'Effra-Bold',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g379[id="sc-2e00ab9a-3"]{content:"iNoavZ,"}/*!sc*/
# .jRkkUq{gap:0.5rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media (min-width:760px){.jRkkUq{gap:1rem;}}/*!sc*/
# data-styled.g380[id="sc-56341d0-0"]{content:"jRkkUq,"}/*!sc*/
# .kYsyzV{top:2.75rem;left:0.4375rem;}/*!sc*/
# data-styled.g381[id="sc-56341d0-1"]{content:"kYsyzV,"}/*!sc*/
# .eCQsLH{gap:0.25rem;-webkit-backdrop-filter:blur(0.75rem);backdrop-filter:blur(0.75rem);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;height:-webkit-fit-content;height:-moz-fit-content;height:fit-content;border-radius:18px;background-color:#e61e14;color:#ffffff;font:bold 0.75rem/1.16 'Effra-Bold',Helvetica,Arial,sans-serif;padding:0.25rem 0.5rem;}/*!sc*/
# .eCQsLH svg{width:0.75rem;height:0.75rem;}/*!sc*/
# @media (min-width:760px){.eCQsLH{font:bold 0.875rem/1.14 'Effra-Bold',Helvetica,Arial,sans-serif;padding:0.25rem 0.5rem;}.eCQsLH svg{width:0.875rem;height:0.875rem;}}/*!sc*/
# .eCQsLH > svg{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:auto;}/*!sc*/
# data-styled.g396[id="sc-52bfb97a-0"]{content:"eCQsLH,"}/*!sc*/
# .bDydkn{aspect-ratio:4/3;gap:1rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;overflow:hidden;margin-bottom:0.5rem;padding:0.5rem;width:100%;border-radius:4px;}/*!sc*/
# data-styled.g446[id="sc-a6df63bf-0"]{content:"bDydkn,"}/*!sc*/
# .SeWj{position:absolute;-webkit-transition:-webkit-transform 250ms ease-in-out;-webkit-transition:transform 250ms ease-in-out;transition:transform 250ms ease-in-out;}/*!sc*/
# data-styled.g447[id="sc-a6df63bf-1"]{content:"SeWj,"}/*!sc*/
# .fwgQzv{position:relative;margin:0;color:#202020;word-break:break-word;font:500 0.875rem/1.29 'Helvetica Neue',Helvetica,Arial,sans-serif;}/*!sc*/
# @media (min-width:760px){.fwgQzv{font:500 1rem/1.375 'Helvetica Neue',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g448[id="sc-a6df63bf-2"]{content:"fwgQzv,"}/*!sc*/
# .jaNhXk{z-index:2;}/*!sc*/
# data-styled.g449[id="sc-a6df63bf-3"]{content:"jaNhXk,"}/*!sc*/
# .cxRmsA{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:column nowrap;-ms-flex-flow:column nowrap;flex-flow:column nowrap;overflow:hidden;width:100%;border:none;background-color:transparent;text-align:left;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;}/*!sc*/
# .cxRmsA:focus-visible{outline:0.125rem solid #e61e14;outline-offset:0.125rem;border-radius:0.125rem;}/*!sc*/
# .cxRmsA:hover .sc-a6df63bf-1{-webkit-transform:perspective(1px) scale3d(1.04,1.04,1.04);-ms-transform:perspective(1px) scale3d(1.04,1.04,1.04);transform:perspective(1px) scale3d(1.04,1.04,1.04);}/*!sc*/
# .cxRmsA:hover .sc-a6df63bf-2{color:#e61e14;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# ...
# .eDvzYF:after{content:'';position:absolute;right:0;bottom:0;left:1rem;background-color:#eeeeee;height:0.0625rem;}/*!sc*/
# .eDvzYF:last-child:after{content:none;}/*!sc*/
# .eDvzYF:first-of-type{margin-top:-1.5rem;}/*!sc*/
# .eDvzYF:last-child{margin-bottom:-1.5rem;border:0;}/*!sc*/
# .eDvzYF .sc-de96cd8-0{padding:0 0 0 1rem;}/*!sc*/
# data-styled.g630[id="sc-e407f288-0"]{content:"eDvzYF,"}/*!sc*/
# .epqLXO{margin:0;padding:1.5rem 0;width:100%;}/*!sc*/
# data-styled.g631[id="sc-e407f288-1"]{content:"epqLXO,"}/*!sc*/
# .edalSZ{margin:0;padding:0;width:100%;list-style-type:'';}/*!sc*/
# data-styled.g632[id="sc-e407f288-2"]{content:"edalSZ,"}/*!sc*/
# .dRgRVh{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:60%;-ms-flex-preferred-size:60%;flex-basis:60%;}/*!sc*/
# @media (min-width:450px){.dRgRVh{-webkit-flex-basis:34%;-ms-flex-preferred-size:34%;flex-basis:34%;}}/*!sc*/
# @media (min-width:760px){.dRgRVh{-webkit-flex-basis:25%;-ms-flex-preferred-size:25%;flex-basis:25%;}}/*!sc*/
# @media (min-width:1100px){.dRgRVh{-webkit-flex-basis:20%;-ms-flex-preferred-size:20%;flex-basis:20%;}}/*!sc*/
# data-styled.g633[id="sc-6f649c31-0"]{content:"dRgRVh,"}/*!sc*/
# .iKWNuk{margin-bottom:2.5rem;}/*!sc*/
# .iKWNuk .sc-673a092e-3{gap:1rem;}/*!sc*/
# @media (min-width:760px){.iKWNuk .sc-673a092e-3{gap:2rem;}}/*!sc*/
# .iKWNuk .sc-2e00ab9a-1{color:#e61e14;}/*!sc*/
# .iKWNuk .sc-102ec126-6,.iKWNuk .sc-102ec126-5{top:5.6875rem;}/*!sc*/
# @media (max-width:calc(760px - 1px)){.iKWNuk .sc-673a092e-1{margin-left:-1rem;margin-right:-1rem;width:calc(100% + 2rem);}.iKWNuk .sc-673a092e-1 .sc-673a092e-2{padding-left:1rem;}}/*!sc*/
# data-styled.g634[id="sc-6f649c31-1"]{content:"iKWNuk,"}/*!sc*/
# .oSBdd{aspect-ratio:4/3;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;overflow:hidden;width:100%;}/*!sc*/
# @media (min-width:760px){.oSBdd{border-radius:0.25rem;}}/*!sc*/
# .oSBdd:before{position:absolute;bottom:0;left:0;z-index:1;display:block;width:100%;height:75%;background:repeating-linear-gradient(180deg,transparent,rgba(0,0,0,0.6));content:'';}/*!sc*/
# data-styled.g635[id="sc-403c6e30-0"]{content:"oSBdd,"}/*!sc*/
# .hWpYIX{position:absolute;-webkit-transition:-webkit-transform 250ms ease-in-out;-webkit-transition:transform 250ms ease-in-out;transition:transform 250ms ease-in-out;}/*!sc*/
# data-styled.g636[id="sc-403c6e30-1"]{content:"hWpYIX,"}/*!sc*/
# .gWQuga{gap:1rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;padding:1rem;}/*!sc*/
# data-styled.g637[id="sc-403c6e30-2"]{content:"gWQuga,"}/*!sc*/
# .kywyAa{position:relative;z-index:2;margin:0;color:#ffffff;word-break:break-word;font:bold 1.375rem/1.09 'Effra-Bold',Helvetica,Arial,sans-serif;}/*!sc*/
# @media (min-width:760px){.kywyAa{font:bold 1.75rem/1.07 'Effra-Bold',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g639[id="sc-403c6e30-4"]{content:"kywyAa,"}/*!sc*/
# .gxIjel{aspect-ratio:4/3;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;overflow:hidden;width:100%;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;}/*!sc*/
# .gxIjel:focus-visible{outline:#e61e14 solid 0.125rem;outline-offset:0.125rem;}/*!sc*/
# .gxIjel:hover .sc-403c6e30-1{-webkit-transform:perspective(1px) scale3d(1.04,1.04,1.04);-ms-transform:perspective(1px) scale3d(1.04,1.04,1.04);transform:perspective(1px) scale3d(1.04,1.04,1.04);}/*!sc*/
# .gxIjel:active .sc-403c6e30-4{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media (min-width:760px){.gxIjel{border-radius:0.25rem;}}/*!sc*/
# data-styled.g640[id="sc-403c6e30-5"]{content:"gxIjel,"}/*!sc*/
# .dKucIF{margin-bottom:0.42rem;color:#666666;text-transform:uppercase;font-size:0.75rem;}/*!sc*/
# data-styled.g645[id="sc-4b43e44b-0"]{content:"dKucIF,"}/*!sc*/
# .cMVPUt{margin:0;padding:0;}/*!sc*/
# data-styled.g646[id="sc-4b43e44b-1"]{content:"cMVPUt,"}/*!sc*/
# .hpoTNM{padding:0 0.375rem;}/*!sc*/
# data-styled.g647[id="sc-4b43e44b-2"]{content:"hpoTNM,"}/*!sc*/
# .bomPLs{color:#202020;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# data-styled.g648[id="sc-4b43e44b-3"]{content:"bomPLs,"}/*!sc*/
# .gZKWko{overflow-wrap:anywhere;display:block;padding:1.5rem 1rem;-webkit-text-decoration:none;text-decoration:none;font-weight:500;}/*!sc*/
# @media (hover:hover) and (pointer:fine),only screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.gZKWko:hover .sc-4b43e44b-3{color:#e61e14;-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .gZKWko:active{color:#202020;}/*!sc*/
# .gZKWko:focus-visible{outline:0.125rem solid #e61e14;outline-offset:0.125rem;border-radius:0.125rem;}/*!sc*/
# data-styled.g649[id="sc-4b43e44b-4"]{content:"gZKWko,"}/*!sc*/
# .gPwIUW{margin:0;padding:1.5rem 0 0;width:100%;}/*!sc*/
# data-styled.g650[id="sc-f255e7e4-0"]{content:"gPwIUW,"}/*!sc*/
# .fiUOWV{margin:0;padding:0;width:100%;list-style-type:none;}/*!sc*/
# data-styled.g651[id="sc-f255e7e4-1"]{content:"fiUOWV,"}/*!sc*/
# .eNBdOw{z-index:2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g661[id="sc-5514cd50-0"]{content:"eNBdOw,"}/*!sc*/
# .jhnSsD{aspect-ratio:4/3;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-align-self:self-start;-ms-flex-item-align:self-start;align-self:self-start;overflow:hidden;padding:0.5rem;max-width:6.5rem;width:33%;border-radius:0.25rem;}/*!sc*/
# .jhnSsD .sc-5514cd50-0{display:none;}/*!sc*/
# @media (min-width:760px){.jhnSsD{width:100%;max-width:unset;}.jhnSsD .sc-5514cd50-0{display:initial;}}/*!sc*/
# data-styled.g662[id="sc-5514cd50-1"]{content:"jhnSsD,"}/*!sc*/
# .byJPZk{-webkit-transition:-webkit-transform 250ms ease-in-out;-webkit-transition:transform 250ms ease-in-out;transition:transform 250ms ease-in-out;}/*!sc*/
# data-styled.g663[id="sc-5514cd50-2"]{content:"byJPZk,"}/*!sc*/
# .iVuIhC{font:500 0.875rem/1.29 'Helvetica Neue',Helvetica,Arial,sans-serif;margin:unset;color:#202020;word-break:break-word;-webkit-transition:color 250ms ease-in-out;transition:color 250ms ease-in-out;}/*!sc*/
# @media (min-width:760px){.iVuIhC{font:bold 1.125rem/1.11 'Effra-Bold',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g664[id="sc-5514cd50-3"]{content:"iVuIhC,"}/*!sc*/
# .gwOzUy{display:none;margin:unset;font:normal 1rem/1.5 'Helvetica Neue',Helvetica,Arial,sans-serif;color:#666666;word-break:break-word;}/*!sc*/
# @media (min-width:760px){.gwOzUy{display:initial;}}/*!sc*/
# data-styled.g665[id="sc-5514cd50-4"]{content:"gwOzUy,"}/*!sc*/
# .nDGdz{gap:0.5rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;}/*!sc*/
# @media (min-width:760px){.nDGdz{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}.nDGdz .sc-5514cd50-0{display:none;}}/*!sc*/
# .lfZPio{gap:0.5rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;width:100%;}/*!sc*/
# @media (min-width:760px){.lfZPio{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}.lfZPio .sc-5514cd50-0{display:none;}}/*!sc*/
# data-styled.g666[id="sc-5514cd50-5"]{content:"nDGdz,lfZPio,"}/*!sc*/
# .jdRlkY{gap:1rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;border-radius:2px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jdRlkY:hover .sc-5514cd50-2{-webkit-transform:perspective(1px) scale3d(1.04,1.04,1.04);-ms-transform:perspective(1px) scale3d(1.04,1.04,1.04);transform:perspective(1px) scale3d(1.04,1.04,1.04);}/*!sc*/
# .jdRlkY:hover:not(:has(button:hover)) .sc-5514cd50-3{color:#e61e14;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .jdRlkY:focus-visible{outline:0.125rem solid #e61e14;outline-offset:0.125rem;border-radius:0.125rem;}/*!sc*/
# .jdRlkY:visited{color:inherit;}/*!sc*/
# @media (min-width:760px){.jdRlkY{padding:0;gap:0.75rem;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# data-styled.g667[id="sc-5514cd50-6"]{content:"jdRlkY,"}/*!sc*/
# .jliyxC{position:absolute;-webkit-transition:-webkit-transform 250ms ease-in-out;-webkit-transition:transform 250ms ease-in-out;transition:transform 250ms ease-in-out;}/*!sc*/
# data-styled.g711[id="sc-40923d84-0"]{content:"jliyxC,"}/*!sc*/
# .dMxJku{z-index:2;}/*!sc*/
# data-styled.g712[id="sc-40923d84-1"]{content:"dMxJku,"}/*!sc*/
# .hmFUPQ{position:relative;z-index:2;margin:0;color:#ffffff;word-break:break-word;font:bold 0.875rem/1.14 'Effra-Bold',Helvetica,Arial,sans-serif;}/*!sc*/
# @media (min-width:760px){.hmFUPQ{font:bold 1rem/1.125 'Effra-Bold',Helvetica,Arial,sans-serif;}}/*!sc*/
# data-styled.g713[id="sc-40923d84-2"]{content:"hmFUPQ,"}/*!sc*/
# .yQqKT{gap:1rem;aspect-ratio:3/4;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;overflow:hidden;padding:0.5rem;width:100%;height:100%;border:none;border-radius:0.25rem;background-color:transparent;text-align:left;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;}/*!sc*/
# .yQqKT:before{position:absolute;bottom:0;left:0;z-index:1;display:block;width:100%;height:75%;background:repeating-linear-gradient(180deg,transparent,rgba(0,0,0,0.6));content:'';}/*!sc*/
# .yQqKT:focus-visible{outline:#e61e14 solid 0.125rem;outline-offset:0.125rem;}/*!sc*/
# .yQqKT:hover .sc-40923d84-0{-webkit-transform:perspective(1px) scale3d(1.04,1.04,1.04);-ms-transform:perspective(1px) scale3d(1.04,1.04,1.04);transform:perspective(1px) scale3d(1.04,1.04,1.04);}/*!sc*/
# .yQqKT:active .sc-40923d84-2{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media (min-width:760px){.yQqKT{padding:1rem;}}/*!sc*/
# data-styled.g714[id="sc-40923d84-3"]{content:"yQqKT,"}/*!sc*/
# .rttwk{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:41%;}/*!sc*/
# @media (min-width:375px){.rttwk{width:32%;}}/*!sc*/
# @media (min-width:600px){.rttwk{width:20%;}}/*!sc*/
# data-styled.g715[id="sc-ac3d8bd1-0"]{content:"rttwk,"}/*!sc*/
# .jueWPN{margin-top:2.5rem;padding-bottom:2.5rem;border-bottom:1px solid #eeeeee;}/*!sc*/
# .jueWPN .sc-673a092e-3{gap:1rem;}/*!sc*/
# @media (min-width:760px){.jueWPN .sc-673a092e-3{gap:1.5rem;}}/*!sc*/
# .jueWPN .sc-2e00ab9a-1{color:#e61e14;}/*!sc*/
# @media (min-width:760px){.jueWPN{border-bottom:none;}}/*!sc*/
# @media (max-width:calc(760px - 1px)){.jueWPN .sc-673a092e-1{margin-left:-1rem;margin-right:-1rem;width:calc(100% + 2rem);}.jueWPN .sc-673a092e-1 .sc-673a092e-2{padding-left:1rem;}}/*!sc*/
# data-styled.g716[id="sc-ac3d8bd1-1"]{content:"jueWPN,"}/*!sc*/
# </style></head><body><div id="__next"><header data-tracking="nestType1=header" class="sc-70b3272e-0 dXvoqD"><ol class="sc-5756b926-0 eYVouA"><li class="sc-5756b926-1 caYZvr"><div class="sc-97bf28f2-0 gOWfGa sc-231324e8-0 sc-5756b926-2 JQmZY ekOwtd"><a href="#content" class="sc-97bf28f2-1 iKAwXw">Ga naar de inhoud</a></div></li></ol><div class="sc-70b3272e-1 jlLrrj"><nav aria-label="Hoofdnavigatie" class="sc-c0b56039-2 bWyhkx"><ul id="menu-expanded" role="list" class="sc-c0b56039-6 csGGQC"><li class="sc-c0b56039-1 fwkWTc"><a data-tracking="eventType=navigation|eventName=open|elementType=page|elementId=home" href="/" class="sc-c0b56039-4 enQSCv"><div class="sc-589e9f18-0 kXgLFt">Homepage</div><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 79 28" aria-hidden="true" class="sc-c0b56039-13 leeTmg"><g fill="none" fill-rule="evenodd"><path fill="currentColor" d="M78.94 18.93c0-5.31-2.57-6.91-9.32-8.54-3.46-.8-4.41-1.27-4.41-2.28 0-.96.53-1.66 2.76-1.66 2.72 0 5.1.93 7.48 2.55 0 0 3.15-5.01 3.49-5.87C76.2 1.12 72.92 0 68.35 0c-6.48 0-10.58 3.44-10.58 8.54 0 5.4 3.1 7.19 9.58 8.7 3.6.84 4.57 1.46 4.57 2.47 0 1.27-.85 1.74-3.5 1.74-2.49 0-5.9-1.36-7.85-2.71l-3.6 5.87a21.3 21.3 0 0 0 11.3 3.29c6.45 0 10.67-2.33 10.67-8.73"></path><path fill="#E61E14" d="M27 13.95C27 6.25 33.32 0 41.12 0s14.13 6.25 14.13 13.95S48.92 27.9 41.12 27.9 27 21.65 27 13.95m7.2 0c0-3.78 3.1-6.84 6.92-6.84 3.83 0 6.93 3.06 6.93 6.84s-3.1 6.84-6.93 6.84a6.89 6.89 0 0 1-6.93-6.84"></path><path fill="currentColor" d="M23.67 27.9V0h-7.33v14.35S6.88 0 6.82 0H.36v27.9h7.32V13.55l9.63 14.35z"></path></g></svg></a></li><li class="sc-79374b6d-0 coISAx sc-c0b56039-0 emjqYd"><a aria-controls="dropdown-voorpagina-laatste nieuws-video&#x27;s-binnenland-buitenland-regionaal nieuws-politiek-economie-koningshuis-tech-cultuur &amp; media-opmerkelijk" aria-expanded="false" data-tracking="eventType=navigation|eventName=open|elementType=page|elementId=home" href="/" class="sc-79374b6d-1 vHpsu">Nieuws <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 9 6" aria-hidden="true" class="sc-c0b56039-12 bezXoB"><path fill="currentColor" d="M4.179 4.865a.45.45 0 0 0 .606.034l.037-.034 3.045-3.08a.464.464 0 0 0 0-.65.45.45 0 0 0-.606-.034l-.037.034L4.5 3.89 1.776 1.135A.45.45 0 0 0 1.17 1.1l-.037.034a.464.464 0 0 0-.033.613l.033.037z"></path></svg></a></li><li class="sc-79374b6d-0 coISAx sc-c0b56039-0 emjqYd"><a aria-controls="dropdown-voorpagina-laatste nieuws-video&#x27;s-voetbal-formule 1-wielrennen-schaatsen-tennis-atletiek-hockey" aria-expanded="false" data-tracking="eventType=navigation|eventName=open|elementType=page|elementId=sport.voorpagina" href="/sport" class="sc-79374b6d-1 gUOeao">Sport <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 9 6" aria-hidden="true" class="sc-c0b56039-12 bezXoB"><path fill="currentColor" d="M4.179 4.865a.45.45 0 0 0 .606.034l.037-.034 3.045-3.08a.464.464 0 0 0 0-.65.45.45 0 0 0-.606-.034l-.037.034L4.5 3.89 1.776 1.135A.45.45 0 0 0 1.17 1.1l-.037.034a.464.464 0 0 0-.033.613l.033.037z"></path></svg></a></li><li class="sc-79374b6d-0 coISAx sc-c0b56039-0 emjqYd"><a data-tracking="eventType=navigation|eventName=open|elementType=page|elementId=live" href="/live" class="sc-79374b6d-1 gUOeao">Live</a></li><li class="sc-79374b6d-0 coISAx sc-c0b56039-0 emjqYd"><a data-tracking="eventType=navigation|eventName=open|elementType=page|elementId=uitzendingen.overzicht" href="/programmas" class="sc-79374b6d-1 gUOeao">Programma&#x27;s</a></li></ul><ul role="list" class="sc-c0b56039-7 kNjOhz"><li class="sc-c0b56039-1 fwkWTc"><a data-tracking="eventType=navigation|eventName=open|elementType=page|elementId=weerpagina" href="/weer" class="sc-c0b56039-5 mTGxJ"><div class="sc-589e9f18-0 kXgLFt">Weer</div><svg xmlns="http://www.w3.org/2000/svg" width="24" height="18" viewBox="0 0 24 18" aria-hidden="true" class="sc-c0b56039-8 jDrBGf"><path fill="currentColor" d="M24 14.52c0 1.8-1.45 3.25-3.25 3.25-.57 0-2 0-5.94.03l-5.95.04A3.25 3.25 0 0 1 8 11.47a3.25 3.25 0 0 1 4-2.9 ...

# %% [markdown]
# ### Posten van data naar een web API
#
# Op [httpbin](https://httpbin.org) staat een hele simpele test-API die je kunt gebruiken. Laten we een dictionary met data via een `POST` request naar de API sturen.

# %%
resultaten = {'cijferlijst':[8,7.2,9], 'diploma': False}

response = requests.post('https://httpbin.org/post', data=resultaten)
print(response.status_code)
response.json()
# Out:
# 200
# {'cijferlijst': ['8', '7.2', '9'], 'diploma': 'False'}

# %% [markdown]
# ## Uitgebreider voorbeeld
#
# Bekijk de [Random Data API](https://random-data-api.com/documentation). Hieronder een wat uitgebreider voorbeeld waarbij:
#
# - Er parameters meegegeven worden aan de request
# - Er gecontroleerd wordt of de status van de response OK is
# - De volledige URL (op basis van de meegegeven parameters) wordt getoond
# - De JSON response wordt geparsed
# - De avatar van de laatste user wordt getoond

# %%
import json
from IPython.display import Image

parameters = {'size': 20, "response_type": 'json'}

response = requests.get("https://random-data-api.com/api/v2/users", params=parameters)
if response.status_code == 200:
    print("De opgevraagde URL was:", response.url)
    users = response.json()
    print("Het aantal ontvangen records is", len(users))
    laatste_user = users[-1]
    print("Het laatste record is:\n", json.dumps(laatste_user, indent=4))
    Image(url=laatste_user['avatar'])
else:
    print('Er ging iets fout..')
# Out:
# De opgevraagde URL was: https://random-data-api.com/api/v2/users?size=20&response_type=json
# Het aantal ontvangen records is 20
# Het laatste record is:
#  {
#     "id": 7771,
#     "uid": "2d1354e2-6328-41d7-a65a-aceb68585545",
#     "password": "OIb9tFZie1",
#     "first_name": "Jame",
#     "last_name": "Zieme",
#     "username": "jame.zieme",
#     "email": "jame.zieme@email.com",
#     "avatar": "https://robohash.org/estautemitaque.png?size=300x300&set=set1",
#     "gender": "Female",
#     "phone_number": "+688 623.423.0256",
#     "social_insurance_number": "559947395",
#     "date_of_birth": "1998-07-12",
#     "employment": {
#         "title": "Direct Farming Manager",
#         "key_skill": "Confidence"
#     },
#     "address": {
#         "city": "Lake Elyse",
#         "street_name": "Patti Hills",
#         "street_address": "263 Heller Locks",
#         "zip_code": "79617",
#         "state": "Arizona",
#         "country": "United States",
#         "coordinates": {
#             "lat": -13.213424175290996,
#             "lng": 30.510239156762992
#         }
#     },
#     "credit_card": {
#         "cc_number": "4798796843287"
#     },
#     "subscription": {
#         "plan": "Student",
#         "status": "Blocked",
#         "payment_method": "WeChat Pay",
#         "term": "Monthly"
#     }
# }
# <img src="https://robohash.org/estautemitaque.png?size=300x300&set=set1"/>

# %% [markdown]
# ## Wat is belangrijk om te weten?
#
# Voor "huis-tuin-en-keuken" gebruik hoef je niet veel methoden van de `requests` library te kennen. Verdiep jezelf vooral in:
#
# - Hoe je data mee kunt geven aan requests
# - Wat voor data je aantreft in het [`Response` object](https://requests.readthedocs.io/en/latest/api.html#requests.Response)
# - De [response status codes](https://requests.readthedocs.io/en/latest/api.html#status-code-lookup).
#
#
# Meer geavanceerde onderwerpen:
#
# - [Authenticatie](https://requests.readthedocs.io/en/latest/user/authentication.html) (in het geval van API's waar je een account nodig hebt/die niet anoniem te gebruiken zijn).
# - [`Session` objecten](https://requests.readthedocs.io/en/latest/user/advanced.html#session-objects) zijn handig als je veelvuldig requests doet bij dezelfde host.
